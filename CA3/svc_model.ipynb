# %%
# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
water_train = pd.read_csv('assets/train.csv', delimiter=',')

# %%
water_train
# Out:
#       Unnamed: 0        ph    Hardness        Solids  Chloramines     Sulfate  \
# 0              0  8.699665  206.379671  20051.663488     7.725750  360.083725
# 1              1  6.563410  175.697020  16117.048403     6.084136  333.778060
# 2              2  6.817023  246.660238  19537.573853     9.051732  317.237871
# 3              3  7.449572  146.902210  19924.425670     7.950549  444.198272
# 4              4  5.300541  212.435573  12624.741570     7.313756  350.452182
# ...          ...       ...         ...           ...          ...         ...
# 2035        2035  5.799883  236.684321  42986.976581     7.000892  321.832742
# 2036        2036  7.838657  159.016086  16736.982494     6.692211  307.230030
# 2037        2037  8.534096  213.223824  13888.405002     6.626447  380.389492
# 2038        2038  6.558423  209.053922  28351.402085     8.198414  311.769807
# 2039        2039  7.226536  174.648095  27872.932805     5.418436  246.557983
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Drinkable
# 0       408.388221       14.859047        76.846364   5.710412          0
# 1       412.632708       11.222295        73.502793   4.459252          1
# 2       464.209418       14.822665        68.918597   4.602564          0
# 3       554.679850       19.483985        72.081011   3.809883          0
# 4       356.512171       19.213205        99.351837   3.841719          1
# ...            ...             ...              ...        ...        ...
# 2035    299.216835       10.689189        84.224603   2.947935          1
# 2036    263.542076       11.868835        58.211472   3.320310          1
# 2037    430.229335       19.191141        82.876058   4.456382          0
# 2038    502.683243       17.984424        89.038904   4.992916          0
# 2039    405.636645       13.306634        87.011168   4.336237          1
#
# [2040 rows x 11 columns]

# %%
X_train = water_train.iloc[:, :10]
y_train = water_train.iloc[:, 10]

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.histplot(data=water_train, ax=ax)
# Out:
# <AxesSubplot:ylabel='Count'>
# <AxesSubplot:ylabel='Count'>
